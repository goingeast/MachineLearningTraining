# %% [markdown]
# # Machine Learning
# - looking for a function from data
# ![Screen%20Shot%202019-09-22%20at%208.27.52%20PM.png](attachment:Screen%20Shot%202019-09-22%20at%208.27.52%20PM.png)
# # Three steps of machine learning
# 1. Define model, a set of functions.
# 2. Define goodness of functions
# 3. Find the best of function.
# # Relation Between Terminology
# ![Screen%20Shot%202019-09-22%20at%208.12.38%20PM.png](attachment:Screen%20Shot%202019-09-22%20at%208.12.38%20PM.png)
